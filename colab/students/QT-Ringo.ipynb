# %% [markdown]
# # Build a Long/Short Pairs Portfolio to maximum the PnL
#
# 1.   Base on **stocksInfo** and **researchData** to **identify  Pairs** and calculate **trading parameters**.
# 2.   Based on **testData** to **backtest** the Pairs portfolio with **signals** and **dollarValue**
# 3.   Calculate the **PnL** of the backtested Pairs portfolio
#
#
#
# # Rules
#
#
# *   **No lookahead bias**: The testData cannot be used for Pairs identification nor the trading parameters calculations
# *   **No overfitting**: The Pairs cannot be hand-picked and must be based on rules. Similarly for the trading parameters and dollarValue, apart from the obvious numbers (e.g. 0.05, 0.1, 0.5, 1, 100, 1000 etc.), they must be based on rules also.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from numba import jit, njit, vectorize, cuda, uint32, f8, uint8
# %load_ext google.colab.data_table 
# %matplotlib inline

# Download and import pairslib for calculating PnL
# !wget https://github.com/kenwkliu/ideas/raw/master/colab/pairslib.py
import pairslib

# Load the stockInfo, researchData and testData
stocksInfo = pd.read_excel('https://raw.githubusercontent.com/kenwkliu/ideas/master/colab/data/hkStocksQuotes.xlsx')
researchData = pd.read_csv('https://raw.githubusercontent.com/kenwkliu/ideas/master/colab/data/researchHKStocksAdjClosePx.csv', index_col=0)
testData = pd.read_csv('https://raw.githubusercontent.com/kenwkliu/ideas/master/colab/data/testHKStocksAdjClosePx.csv', index_col=0)
# Out:
# --2021-10-28 09:33:05--  https://github.com/kenwkliu/ideas/raw/master/colab/pairslib.py
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/kenwkliu/ideas/master/colab/pairslib.py [following]
# --2021-10-28 09:33:06--  https://raw.githubusercontent.com/kenwkliu/ideas/master/colab/pairslib.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2949 (2.9K) [text/plain]
# Saving to: ‘pairslib.py’
#
# pairslib.py         100%[===================>]   2.88K  --.-KB/s    in 0s
#
# 2021-10-28 09:33:06 (26.7 MB/s) - ‘pairslib.py’ saved [2949/2949]

# %%
# !pip install tslearn
# !pip install numba
# !find / -iname 'libdevice'
# !find / -iname 'libnvvm.so'
# Out:
# Collecting tslearn
#   Downloading tslearn-0.5.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (793 kB)
#      |████████████████████████████████| 793 kB 5.3 MB/s
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from tslearn) (0.29.24)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tslearn) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from tslearn) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from tslearn) (1.4.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from tslearn) (0.51.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from tslearn) (1.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->tslearn) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba->tslearn) (0.34.0)
# Installing collected packages: tslearn
# Successfully installed tslearn-0.5.2
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (0.51.2)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba) (57.4.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from numba) (1.19.5)
# /usr/local/lib/python3.7/dist-packages/jaxlib/cuda/nvvm/libdevice
# /usr/local/cuda-11.1/nvvm/libdevice
# /usr/local/cuda-10.0/nvvm/libdevice
# /usr/local/cuda-10.1/nvvm/libdevice
# /usr/local/cuda-11.0/nvvm/libdevice
# /usr/local/cuda-11.1/nvvm/lib64/libnvvm.so
# /usr/local/cuda-10.0/nvvm/lib64/libnvvm.so
# /usr/local/cuda-10.1/nvvm/lib64/libnvvm.so
# /usr/local/cuda-11.0/nvvm/lib64/libnvvm.so

# %%
stocksInfo['turnover'] = round(stocksInfo['regularMarketPreviousClose'] * stocksInfo['averageDailyVolume10Day'])

QUOTE_TYPE = 'EQUITY'
MIN_TURNOVER = 100000000  # 100 millions
SELECTED_COLUMNS = ['code', 'shortName', 'industry', 'sector', 'turnover']

stocksFilteredInfo = stocksInfo[(stocksInfo.quoteType == QUOTE_TYPE) & (stocksInfo.turnover > MIN_TURNOVER) & (stocksInfo.industry != 'ETF')].reset_index()
stocksFilteredInfo.sort_values(by=['turnover'], ascending=False)[SELECTED_COLUMNS]

def getCorrelatedPairs(stocksCorr, THRESHOLD=0.95):
    # filter the pairs with correlation values above the THRESHOLD
    highCorr = stocksCorr[((stocksCorr >= THRESHOLD) & (stocksCorr < 1))]
    highCorr = highCorr.unstack().sort_values(ascending=False).drop_duplicates()
    highCorr.dropna(inplace=True)
    highCorrDf = highCorr.to_frame().reset_index()
    highCorrDf.rename(columns = {'level_0':'stockA', 'level_1':'stockB', 0:'corr'}, inplace=True)

    # looks up the sectors for the stocksA and stockB
    cols = ['stockA', 'stockB', 'corr', 'sector_A', 'sector_B']
    pairsDf = highCorrDf.merge(stocksFilteredInfo[['shortName', 'sector']], how='left', left_on='stockA', right_on='shortName').merge(stocksFilteredInfo[['shortName', 'sector']], how='left', left_on='stockB', right_on='shortName', suffixes=('_A', '_B'))[cols]
    pairsDf['sameSector'] = (pairsDf['sector_A'] == pairsDf['sector_B'])
    return pairsDf

pairsDf = getCorrelatedPairs(researchData.corr())
pairsDf
# Out:
#              stockA           stockB  ...                       sector_B sameSector
# 0       XINYI SOLAR       FLAT GLASS  ...                  Glass strands      False
# 1      MEIDONG AUTO        MEITUAN-W  ...        E-commerce and Internet      False
# 2      ZIJIN MINING    MAN WAH HLDGS  ...                     Housewares      False
# 3   ZHONGSHENG HLDG          TENCENT  ...        Online and Mobile Games      False
# 4       XINYI GLASS      XINYI SOLAR  ...             Photovoltaic Solar      False
# ..              ...              ...  ...                            ...        ...
# 59  GREATWALL MOTOR     ZIJIN MINING  ...                Precious metals      False
# 60      CG SERVICES  EVERSUNSHINE LS  ...  Property Management and Agent       True
# 61      WUXI APPTEC          TENCENT  ...        Online and Mobile Games      False
# 62       GEELY AUTO  CHINASOFT INT'L  ...        Technology and Software      False
# 63      HUABAO INTL     CHINA YOUZAN  ...        E-commerce and Internet      False
#
# [64 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import Normalizer
from tslearn.clustering import TimeSeriesKMeans

stock_names = researchData.columns #173 items, 249 days/A year

researchdata_np = researchData.reset_index(drop=True)
researchdata_np = researchdata_np.T.reset_index(drop=True)

researchdata_np = np.array(researchdata_np)
researchdata_np[np.isnan(researchdata_np)] = 300

normalizer = Normalizer()
researchData_np_normalised = normalizer.fit_transform(researchdata_np)

km3 = KMeans(n_clusters=3)
km3.fit(researchData_np_normalised)
km3_labels = km3.labels_

km4 = KMeans(n_clusters=4)
km4.fit(researchData_np_normalised)
km4_labels = km4.labels_

km10 = KMeans(n_clusters=10)
km10.fit(researchData_np_normalised)
km10_labels = km10.labels_

km15 = KMeans(n_clusters=15)
km15.fit(researchData_np_normalised)
km15_labels = km15.labels_

km20 = KMeans(n_clusters=20)
km20.fit(researchData_np_normalised)
km20_labels = km20.labels_

# Run time takes too long...
tskm = TimeSeriesKMeans(n_clusters=5, metric="dtw")
tskm.fit(researchData_np_normalised)
tskm_labels = tskm.labels_
# Out:
# /usr/local/lib/python3.7/dist-packages/tslearn/clustering/kmeans.py:17: UserWarning: Scikit-learn <0.24 will be deprecated in a future release of tslearn
#   "Scikit-learn <0.24 will be deprecated in a "

# %%
# 1. Conduct PCA pairing,
# 2. For each pair, do Augmented Dickey-Fuller test
import numba
from statsmodels.tsa.stattools import adfuller

#@numba.jit
def get_pairs(column_name, labels, data, st):

    data[np.isnan(data)] = 300
    #data.fillna(0)
    clusters = {} 
    adfuller_lb = 0
    adfuller_ub = 0.05
    
    stat_test = st 

    assert len(column_name) == len(labels)
    for cn, la in zip(column_name, labels):

        if la not in clusters:
            clusters[la] = [cn]
        else:
            clusters[la] += [cn]

    pairs = []
    for key, val in clusters.items():
        if len(val) <= 1:
            continue

        for i in val:
            for j in val:
              if i != j:

                this_pair = data[[i, j]].copy()
                
                this_stock_pair_diff = this_pair[i] - this_pair[j]
                adfuller_result = stat_test(this_stock_pair_diff)
                p_value = adfuller_result[1]
                if adfuller_lb< p_value and p_value < adfuller_ub:
                    pairs.append((i, j))
    
    return pairs

my_trading_pairs = get_pairs(stock_names, tskm_labels, researchData, adfuller)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
print(len(my_trading_pairs))
np.savetxt(f"pairs_{len(my_trading_pairs)}.csv", 
           my_trading_pairs,
           delimiter =", ", 
           fmt ='% s')
# Out:
# 768

# %%
# Implement your logic to construct "pairsBackTest"
# pairsBackTest needs to be same format as in https://colab.research.google.com/github/kenwkliu/ideas/blob/master/colab/HKStocksCorrelation.ipynb
# It is a list of backtested Pairs
# Each backtested Pairs is a dataframe with at least these columns (Date, stockA, stockB, signal, dollarValue)

# signal is -1, 0, 1
# signal == -1: Long stockA Short stockB
# signal == 1: Short stockA Long stockB
# signal == 0: flat position
PAIR_STOCK_A, PAIR_STOCK_B = "HANG SENG BANK", "HSBC HOLDINGS"

pairResearchData = researchData[[PAIR_STOCK_A, PAIR_STOCK_B]].copy()
AB_stock = PAIR_STOCK_A + " / " + PAIR_STOCK_B
pairResearchData[AB_stock] = pairResearchData[PAIR_STOCK_A] / pairResearchData[PAIR_STOCK_B]
pairResearchData[[PAIR_STOCK_A, PAIR_STOCK_B, AB_stock]]
# Out:
#             HANG SENG BANK  HSBC HOLDINGS  HANG SENG BANK / HSBC HOLDINGS
# Date
# 2020-01-02      149.835770      58.445934                        2.563665
# 2020-01-03      149.281525      57.966084                        2.575325
# 2020-01-06      148.080612      57.582199                        2.571639
# 2020-01-07      148.727264      57.486233                        2.587181
# 2020-01-08      148.265396      56.910408                        2.605242
# ...                    ...            ...                             ...
# 2020-12-24      127.932472      38.726341                        3.303500
# 2020-12-28      128.996964      38.533676                        3.347642
# 2020-12-29      129.093719      38.774513                        3.329345
# 2020-12-30      130.254990      39.111679                        3.330335
# 2020-12-31      129.480820      39.159851                        3.306469
#
# [249 rows x 3 columns]

# %%
# This is the original back-testing function
def researchTradingParams(researchData, stockA, stockB, threshold=0.05, dollarValue=10000):
    cols = [stockA, stockB]
    research_df = researchData[cols].copy()
    research_df.dropna(inplace = True)

    tradingParams = {}
    tradingParams['dollarValue'] = dollarValue

    # Calculate avgPxRatio for Exit (convergence)
    research_df['ratio'] = research_df[stockA] / research_df[stockB]
    avgPxRatio = research_df['ratio'].mean()
    tradingParams['avgPxRatio'] = avgPxRatio

    # Calculate shortA_longB_ratio for Entry (Divergence)
    shortA_longB_ratio = avgPxRatio * (1 + threshold)
    tradingParams['shortA_longB_ratio'] = shortA_longB_ratio

    # Calculate longA_shortB_ratio from Entry (Divergence)
    longA_shortB_ratio = avgPxRatio * (1 - threshold)
    tradingParams['longA_shortB_ratio'] = longA_shortB_ratio

    return tradingParams

def backTest(testData, tradingParams, stockA, stockB):
    cols = [stockA, stockB]
    backTest_df = testData[cols].copy()
    backTest_df.dropna(inplace = True)

    # Get the tradingParams
    dollarValue = tradingParams['dollarValue']
    avgPxRatio = tradingParams['avgPxRatio']
    shortA_longB_ratio = tradingParams['shortA_longB_ratio']
    longA_shortB_ratio = tradingParams['longA_shortB_ratio']

    # Calculate the Price ratio in backTest_df
    backTest_df['pxRatio'] = backTest_df[stockA] / backTest_df[stockB]
    backTest_df['dollarValue'] = dollarValue
    
    # initialize the signal to 0
    backTest_df['signal'] = 0
    signal = 0

    # Determine the signal in each row of the backTest_df
    for index, row in backTest_df.iterrows():

      pxRatio = row['pxRatio']

      # mark signal = 1 if pxRatio > shortA_longB_ratio (Diverge outside the upper band)
      if pxRatio > shortA_longB_ratio:
        signal = 1

      # mark signal = -1 if pxRatio < longA_shortB_ratio (Diverge outside the lower band)
      elif pxRatio < longA_shortB_ratio:
        signal = -1

      else:
        # continue to mark signal = 1 if previous signal == 1 and pxRatio > avgPxRatio (Trade entered but not converge back yet)
        if signal == 1 and pxRatio > avgPxRatio:
          signal = 1

        # continue to mark signal = -1 if previous signal == -1 and pxRatio < avgPxRatio (Trade entered but not converge back yet)
        elif signal == -1 and pxRatio < avgPxRatio:
          signal = -1

        else:
          signal = 0

      backTest_df.loc[index, 'signal'] = signal

    return backTest_df

PX_RATIO_THRESHOLD = 0.05
tradingParams = researchTradingParams(pairResearchData, PAIR_STOCK_A, PAIR_STOCK_B, PX_RATIO_THRESHOLD)
backTest_df = backTest(testData, tradingParams, PAIR_STOCK_A, PAIR_STOCK_B)

# Calcuate the PnL in test period
pnl, pnl_df = pairslib.calcPnl(backTest_df)
print("Reference PnL: ", pnl)
# Out:
# Reference PnL:  1552.0709377264266

# %%
def researchTradingParams(researchData, stockA, stockB, threshold=0.05, dollarValue=10000):
    cols = [stockA, stockB]
    research_df = researchData[cols].copy()
    
    research_df[stockA].fillna(value=research_df[stockA].mean(), inplace=True)
    research_df[stockB].fillna(value=research_df[stockB].mean(), inplace=True)
    
    #research_df.dropna(inplace = True)
    #research_df[stockA][np.isnan(data)] = 300

    tradingParams = {}
    tradingParams['dollarValue'] = dollarValue

    # Calculate avgPxRatio for Exit (convergence)
    research_df['spread'] = research_df[stockA] - research_df[stockB]
    
    avgPxRatio = research_df['spread'].mean()
    tradingParams['avgPxRatio'] = avgPxRatio

    # Calculate Positive Thresholding
    df_mean = research_df['spread'].mean()
    df_std = research_df['spread'].std()

    #print('df_mean, df_std: ', df_mean, df_std)
    # Assuming Normal distribution
    upper_tail = df_mean + 0.725*df_std
    lower_tail = df_mean - 0.725*df_std

    tradingParams['upper_tail'] = upper_tail
    tradingParams['lower_tail'] = lower_tail
    tradingParams['mean'] = df_mean
    tradingParams['std'] = df_std

    return tradingParams

def backTest(testData, tradingParams, stockA, stockB):
    cols = [stockA, stockB]
    backTest_df = testData[cols].copy()
    backTest_df.dropna(inplace = True)

    # Get the tradingParams
    dollarValue = tradingParams['dollarValue']
    backTest_df['dollarValue'] = dollarValue

    df_mean = tradingParams['mean']
    df_std = tradingParams['std']
    upper_tail = df_mean + 0.725*df_std
    lower_tail = df_mean - 0.725*df_std

    # initialize the signal to 0
    backTest_df['signal'] = 0
    signal = 0

    # Determine the signal in each row of the backTest_df
    for index, row in backTest_df.iterrows():
      
      if index == 0:
        df_std = df_std
      else:
        df_std = df_std + 0.1*np.random.normal() # simple voliatilty modelling

      spread = row[stockA] - row[stockB]

      # mark signal = 1 if pxRatio > shortA_longB_ratio (Diverge outside the upper band)
      if spread < df_mean + 0.725*df_std:
        signal = 1

      # mark signal = -1 if pxRatio < longA_shortB_ratio (Diverge outside the lower band)
      elif spread > df_mean - 0.725*df_std:
        signal = -1

      else:
        # continue to mark signal = 1 if previous signal == 1 and pxRatio > avgPxRatio (Trade entered but not converge back yet)
        if signal == 1 and spread > df_mean  :
          signal = 1

        # continue to mark signal = -1 if previous signal == -1 and pxRatio < avgPxRatio (Trade entered but not converge back yet)
        elif signal == -1 and spread < df_mean :
          signal = -1

        else:
          signal = 0

      backTest_df.loc[index, 'signal'] = signal

    return backTest_df

# Idea calculate threshold t+1 given t, t-1, t-2, t-3, t-5

# %%
# Calcuate the PnL of the Pairs portfolio
pairsBackTest = []

for a,b in my_trading_pairs:
    stockA, stockB = a, b

    my_tradingParams = researchTradingParams(researchData, stockA, stockB)
    my_backTest_df = backTest(testData, my_tradingParams, stockA, stockB)
    pnl, pnl_df = pairslib.calcPnl(my_backTest_df)
    pairsBackTest.append(my_backTest_df[[stockA, stockB, 'signal', 'dollarValue']])

pnl, pnlDf = pairslib.calcPortfolio(pairsBackTest)
pnlDf
# Out:
# BABA-SW vs TECHTRONIC IND ---> $ 6903.274135824227
# BABA-SW vs YIHAI INTL ---> $ -4201.018185919497
# BABA-SW vs PHARMARON ---> $ 7584.42161635362
# TENCENT vs MEITUAN-W ---> $ -286.63763623058276
# MEITUAN-W vs TENCENT ---> $ 370.1306188378876
# PING AN vs ASM PACIFIC ---> $ 2920.0918565642987
# SHK PPT vs GANFENGLITHIUM ---> $ 3712.0467892696015
# SHK PPT vs LINK REIT ---> $ -1569.28980099999
# ANTA SPORTS vs GANFENGLITHIUM ---> $ 153.90612333868103
# CLP HOLDINGS vs HENGAN INT'L ---> $ 1784.9875626017838
# SUNNY OPTICAL vs GANFENGLITHIUM ---> $ -5739.76280855715
# TECHTRONIC IND vs BABA-SW ---> $ 6404.192130910105
# YIHAI INTL vs BABA-SW ---> $ -495.8548428427712
# HENGAN INT'L vs CLP HOLDINGS ---> $ 2580.123027147608
# ASM PACIFIC vs PING AN ---> $ 2478.607119123586
# PHARMARON vs BABA-SW ---> $ 7584.42161635362
# GANFENGLITHIUM vs SHK PPT ---> $ 3712.0467892696015
# GANFENGLITHIUM vs ANTA SPORTS ---> $ -1556.5968022074612
# GANFENGLITHIUM vs SUNNY OPTICAL ---> $ -4722.728600454877
# LINK REIT vs SHK PPT ---> $ 178.6376871534867
# CCB vs ICBC ---> $ 251.11186090608498
# CCB vs BANK OF CHINA ---> $ 341.09694267368104
# CCB vs COUNTRY GARDEN ---> $ -1421.9777081307748
# CCB vs WH GROUP ---> $ -428.3606518836932
# CCB vs SINOPEC CORP ---> $ 2982.216743626983
# CCB vs ABC ---> $ -152.93336253741109
# CCB vs PETROCHINA ---> $ 5677.373921043483
# CCB vs GREENTOWN SER ---> $ 958.282847097069
# CCB vs GOME RETAIL ---> $ -978.7283901108312
# ICBC vs CCB ---> $ -153.14155216858853
# ICBC vs BANK OF CHINA ---> $ 2684.05894651397
# ICBC vs COUNTRY GARDEN ---> $ -1653.54642152837
# ICBC vs WH GROUP ---> $ -802.4681114368996
# ICBC vs SINOPEC CORP ---> $ 2810.996234863489
# ICBC vs ABC ---> $ 2.9111441903478408
# ICBC vs PETROCHINA ---> $ 3227.0624339351707
# ICBC vs GREENTOWN SER ---> $ 807.4546752898132
# ICBC vs HAITONG SEC ---> $ 1222.2219736009465
# BANK OF CHINA vs CCB ---> $ 195.00615539429236
# BANK OF CHINA vs ICBC ---> $ 137.4660842078265
# BANK OF CHINA vs COUNTRY GARDEN ---> $ -3282.138642846803
# BANK OF CHINA vs WH GROUP ---> $ 1004.4451374260079
# BANK OF CHINA vs SINOPEC CORP ---> $ 942.1318149786694
# BANK OF CHINA vs CITIC BANK ---> $ -714.6332651750599
# BANK OF CHINA vs GREENTOWN SER ---> $ 820.9833680281754
# BANK OF CHINA vs HAITONG SEC ---> $ -724.7467517550704
# BANK OF CHINA vs ZHAOJIN MINING ---> $ 4160.531453915
# COUNTRY GARDEN vs CCB ---> $ 2044.231636858728
# COUNTRY GARDEN vs ICBC ---> $ 1265.0009203331556
# COUNTRY GARDEN vs BANK OF CHINA ---> $ 2344.583477080926
# COUNTRY GARDEN vs SINOPEC CORP ---> $ 3994.8445671569816
# COUNTRY GARDEN vs ABC ---> $ 2209.342943749454
# COUNTRY GARDEN vs PETROCHINA ---> $ 8523.077879287304
# COUNTRY GARDEN vs KUNLUN ENERGY ---> $ 8542.36302577405
# COUNTRY GARDEN vs CIFI HOLD GP ---> $ 554.8573594242989
# COUNTRY GARDEN vs GREENTOWN SER ---> $ 794.5522942428515
# COUNTRY GARDEN vs CHINA TELECOM ---> $ 4689.858870283599
# COUNTRY GARDEN vs AVICHINA ---> $ -538.4716912582362
# COUNTRY GARDEN vs CHINA YOUZAN ---> $ -4490.218665896859
# COUNTRY GARDEN vs FIT HON TENG ---> $ -3471.529578941133
# COUNTRY GARDEN vs GOME RETAIL ---> $ 1098.6703839764432
# COUNTRY GARDEN vs PICC GROUP ---> $ 1603.5738451262996
# COUNTRY GARDEN vs HENGTEN NET ---> $ -638.3459442592157
# COUNTRY GARDEN vs CGS ---> $ 1912.0906618004628
# COUNTRY GARDEN vs HOPE EDU ---> $ -1173.4214515238218
# COUNTRY GARDEN vs COFCO MEAT ---> $ -247.94421535462607
# COUNTRY GARDEN vs CMOC ---> $ 878.5510037599761
# COUNTRY GARDEN vs ZHAOJIN MINING ---> $ 2111.3999561608052
# COUNTRY GARDEN vs CHINA DONGXIANG ---> $ 2408.7993427969877
# HK & CHINA GAS vs PICC P&C ---> $ 780.8091225230764
# SINO BIOPHARM vs BRILLIANCE CHI ---> $ -433.44463088176053
# SINO BIOPHARM vs 3SBIO ---> $ 1809.0269205832656
# WH GROUP vs CCB ---> $ 1609.3892878148235
# WH GROUP vs ICBC ---> $ 1849.2553776534114
# WH GROUP vs BANK OF CHINA ---> $ 1468.712786117243
# WH GROUP vs SINOPEC CORP ---> $ 3574.927887016782
# WH GROUP vs ABC ---> $ 1647.3996178966972
# WH GROUP vs PETROCHINA ---> $ 8289.277679396497
# WH GROUP vs CITIC BANK ---> $ 3942.7445445545636
# WH GROUP vs PICC P&C ---> $ 3711.1228283152495
# WH GROUP vs MINSHENG BANK ---> $ 2045.710879123013
# WH GROUP vs GREENTOWN SER ---> $ 1542.9275559128164
# WH GROUP vs CHINA TELECOM ---> $ -566.716105717127
# WH GROUP vs HAITONG SEC ---> $ 2155.4404689002076
# WH GROUP vs GOME RETAIL ---> $ -701.5346997276602
# WH GROUP vs PICC GROUP ---> $ 702.4123032027946
# WH GROUP vs CHINA DONGXIANG ---> $ -95.3526323069218
# SINOPEC CORP vs CCB ---> $ -1141.7336126759437
# SINOPEC CORP vs ICBC ---> $ 3046.264545242533
# SINOPEC CORP vs BANK OF CHINA ---> $ 1876.2255712394126
# SINOPEC CORP vs COUNTRY GARDEN ---> $ 1500.7730806124073
# SINOPEC CORP vs WH GROUP ---> $ 2721.9438203608815
# SINOPEC CORP vs CITIC BANK ---> $ -848.6057405989304
# SINOPEC CORP vs GREENTOWN SER ---> $ 2429.396433370408
# SINOPEC CORP vs HAITONG SEC ---> $ 693.2352810806879
# SINOPEC CORP vs AIR CHINA ---> $ 180.5306701036552
# SINOPEC CORP vs ZHAOJIN MINING ---> $ 4101.768474050396
# ABC vs CCB ---> $ 96.51229058907484
# ABC vs ICBC ---> $ -714.1811225974361
# ABC vs COUNTRY GARDEN ---> $ 1504.9745825318605
# ABC vs WH GROUP ---> $ -1508.03283579223
# ABC vs GREENTOWN SER ---> $ -64.0188105463294
# ABC vs HAITONG SEC ---> $ 1099.3272042316985
# ABC vs ZHAOJIN MINING ---> $ 1868.3374775933362
# CHINARES CEMENT vs SJM HOLDINGS ---> $ -1684.3755085016219
# CHINARES CEMENT vs HENGTEN NET ---> $ -2140.1315523585217
# CHINARES CEMENT vs COFCO MEAT ---> $ 305.62209174027157
# CHINA JINMAO vs GREENTOWN SER ---> $ 1286.1868407767452
# PETROCHINA vs CCB ---> $ 2679.1437814093024
# PETROCHINA vs ICBC ---> $ 92.12574885540744
# PETROCHINA vs COUNTRY GARDEN ---> $ 7052.324250994365
# PETROCHINA vs WH GROUP ---> $ 5492.773164108839
# PETROCHINA vs CITIC BANK ---> $ 4573.452725546535
# PETROCHINA vs GREENTOWN SER ---> $ 107.68639685656672
# PETROCHINA vs CHINA TELECOM ---> $ 2352.5978205816573
# PETROCHINA vs HAITONG SEC ---> $ 2489.0465465325815
# PETROCHINA vs GOME RETAIL ---> $ 8812.786920234168
# PETROCHINA vs HOPE EDU ---> $ 6548.2284505468815
# PETROCHINA vs ZHAOJIN MINING ---> $ 3413.7888984645615
# PETROCHINA vs CHINA DONGXIANG ---> $ 3514.462356544149
# KUNLUN ENERGY vs COUNTRY GARDEN ---> $ 8542.36302577405
# KUNLUN ENERGY vs CIFI HOLD GP ---> $ 6466.033496524564
# KUNLUN ENERGY vs ZHAOJIN MINING ---> $ 10676.008435003234
# CIFI HOLD GP vs COUNTRY GARDEN ---> $ -1774.55945238172
# CIFI HOLD GP vs KUNLUN ENERGY ---> $ 8134.308262707311
# CIFI HOLD GP vs BRILLIANCE CHI ---> $ 1336.018437044404
# CIFI HOLD GP vs GREENTOWN SER ---> $ 1566.730649077408
# CIFI HOLD GP vs CHINA YOUZAN ---> $ 1365.6163382371205
# CIFI HOLD GP vs FIT HON TENG ---> $ -491.77206047552954
# CIFI HOLD GP vs GOME RETAIL ---> $ -2175.375694157282
# CIFI HOLD GP vs CGS ---> $ 2914.6473460811394
# CIFI HOLD GP vs HOPE EDU ---> $ 793.7804484417493
# CIFI HOLD GP vs COFCO MEAT ---> $ -1559.6477426146048
# CIFI HOLD GP vs ZHAOJIN MINING ---> $ 2366.8470649715973
# CIFI HOLD GP vs CHINA DONGXIANG ---> $ 1379.6669170142322
# CITIC BANK vs BANK OF CHINA ---> $ -152.53723009850728
# CITIC BANK vs WH GROUP ---> $ -278.3948502381245
# CITIC BANK vs SINOPEC CORP ---> $ 860.7272025791153
# CITIC BANK vs PETROCHINA ---> $ 1310.0406724383029
# CITIC BANK vs GREENTOWN SER ---> $ 54.15468339121617
# CITIC BANK vs HAITONG SEC ---> $ -123.4941426476671
# CITIC BANK vs HOPE EDU ---> $ 1909.8357251111538
# CITIC BANK vs ZHAOJIN MINING ---> $ 1405.4157286248528
# SJM HOLDINGS vs CHINARES CEMENT ---> $ 2222.816152977609
# SJM HOLDINGS vs KWG GROUP ---> $ 879.7082084047124
# SJM HOLDINGS vs AVICHINA ---> $ -148.64402011906714
# SJM HOLDINGS vs ZHAOJIN MINING ---> $ -1239.0563337569383
# SJM HOLDINGS vs COMEC ---> $ 2025.4934470965245
# CHINA SHENHUA vs CHINA YOUZAN ---> $ 7335.232244959423
# CHINA SHENHUA vs HENGTEN NET ---> $ 13422.417197906885
# CHINA SHENHUA vs CHINASOFT INT'L ---> $ 2719.7362244242595
# CHINA SHENHUA vs ZOOMLION ---> $ 2634.282125194529
# CHINA SHENHUA vs ZHAOJIN MINING ---> $ 8265.454507072289
# PICC P&C vs HK & CHINA GAS ---> $ 1271.945701663437
# PICC P&C vs WH GROUP ---> $ 204.88343765498212
# PICC P&C vs GREENTOWN SER ---> $ -490.5533236077299
# PICC P&C vs FI2 CSOP HSI ---> $ 2784.060313609032
# CNBM vs AVICHINA ---> $ -4241.455207389197
# CNBM vs HENGTEN NET ---> $ 6222.493741680585
# CNBM vs COFCO MEAT ---> $ 6406.363946748324
# CNBM vs ZOOMLION ---> $ -4591.347802834298
# MINSHENG BANK vs WH GROUP ---> $ 641.117561936906
# MINSHENG BANK vs GREENTOWN SER ---> $ -1078.0526124724547
# KWG GROUP vs SJM HOLDINGS ---> $ 692.4001602297767
# KWG GROUP vs AVICHINA ---> $ -1555.4514019868893
# KWG GROUP vs CHINA YOUZAN ---> $ 4788.097833842837
# KWG GROUP vs HENGTEN NET ---> $ -4603.985585619948
# KWG GROUP vs ZHAOJIN MINING ---> $ 198.9984232289553
# KWG GROUP vs COMEC ---> $ -1359.0186280532025
# KWG GROUP vs EB SECURITIES ---> $ 2393.653623782854
# BRILLIANCE CHI vs SINO BIOPHARM ---> $ -432.60954929537365
# BRILLIANCE CHI vs CIFI HOLD GP ---> $ 1173.457095062986
# BRILLIANCE CHI vs GREENTOWN SER ---> $ 3570.24705243314
# BRILLIANCE CHI vs FIT HON TENG ---> $ 3213.7637360548906
# BRILLIANCE CHI vs GOME RETAIL ---> $ 3972.810120248507
# BRILLIANCE CHI vs HOPE EDU ---> $ 1279.5776695218465
# BRILLIANCE CHI vs COFCO MEAT ---> $ 2731.429830164865
# BRILLIANCE CHI vs ZHAOJIN MINING ---> $ 1640.001341344907
# BRILLIANCE CHI vs CHINA DONGXIANG ---> $ -459.25724640683984
# ND PAPER vs ZIJIN MINING ---> $ 878.694798177763
# ND PAPER vs CHINASOFT INT'L ---> $ 5135.404552992013
# GREENTOWN SER vs CCB ---> $ 633.5545947614137
# GREENTOWN SER vs ICBC ---> $ 2099.7760887379372
# GREENTOWN SER vs BANK OF CHINA ---> $ 2463.593977976314
# GREENTOWN SER vs COUNTRY GARDEN ---> $ -974.9742141924362
# GREENTOWN SER vs WH GROUP ---> $ 2092.2052272904602
# GREENTOWN SER vs SINOPEC CORP ---> $ 3173.0890069796787
# GREENTOWN SER vs ABC ---> $ 3706.1881714079964
# GREENTOWN SER vs CHINA JINMAO ---> $ 2157.195840383549
# GREENTOWN SER vs PETROCHINA ---> $ 2399.563866927094
# GREENTOWN SER vs CIFI HOLD GP ---> $ 1888.321611043617
# GREENTOWN SER vs CITIC BANK ---> $ 2085.916330150755
# GREENTOWN SER vs PICC P&C ---> $ 3355.4784400848785
# GREENTOWN SER vs MINSHENG BANK ---> $ 179.96754220571256
# GREENTOWN SER vs BRILLIANCE CHI ---> $ 289.3695858023402
# GREENTOWN SER vs CHINA TELECOM ---> $ 903.2702172129193
# GREENTOWN SER vs HAITONG SEC ---> $ 1932.308829993328
# GREENTOWN SER vs GOME RETAIL ---> $ 8499.478598143129
# GREENTOWN SER vs PICC GROUP ---> $ 2534.2412248904584
# GREENTOWN SER vs AIR CHINA ---> $ 716.8639278429182
# GREENTOWN SER vs CGS ---> $ 796.1620901408733
# GREENTOWN SER vs HOPE EDU ---> $ 4750.702877203306
# GREENTOWN SER vs COFCO MEAT ---> $ 4028.333302355757
# GREENTOWN SER vs CHINA DONGXIANG ---> $ -3190.0764128682285
# CHINA TELECOM vs COUNTRY GARDEN ---> $ -6594.666475283055
# CHINA TELECOM vs WH GROUP ---> $ -806.6285220382997
# CHINA TELECOM vs PETROCHINA ---> $ 6166.7189090028405
# CHINA TELECOM vs GREENTOWN SER ---> $ -3265.2088146363058
# CHINA TELECOM vs HAITONG SEC ---> $ -2464.1588616259214
# CHINA TELECOM vs ZHAOJIN MINING ---> $ 2355.2400059852107
# AVICHINA vs COUNTRY GARDEN ---> $ -538.4716912582362
# AVICHINA vs SJM HOLDINGS ---> $ 2239.2188946852357
# AVICHINA vs CNBM ---> $ 975.6950791762902
# AVICHINA vs KWG GROUP ---> $ -1857.9241941827004
# AVICHINA vs ZOOMLION ---> $ 4614.484514279923
# AVICHINA vs ZHAOJIN MINING ---> $ 1595.173717970948
# AVICHINA vs EB SECURITIES ---> $ -2010.6724567576948
# CHINA YOUZAN vs COUNTRY GARDEN ---> $ -1117.7849807870634
# CHINA YOUZAN vs CIFI HOLD GP ---> $ 6312.739365989002
# CHINA YOUZAN vs CHINA SHENHUA ---> $ 8633.72915126189
# CHINA YOUZAN vs KWG GROUP ---> $ 7775.991146597224
# CHINA YOUZAN vs CGS ---> $ 1260.7481113698086
# CHINA YOUZAN vs ZHAOJIN MINING ---> $ -2356.573256667675
# CHINA YOUZAN vs EB SECURITIES ---> $ 7697.386869197037
# ZIJIN MINING vs ND PAPER ---> $ 94.61679525088311
# ZIJIN MINING vs YONGDA AUTO ---> $ 123.16800014863566
# JXR vs DONGFENG GROUP ---> $ 1051.7205353717045
# FIT HON TENG vs COUNTRY GARDEN ---> $ -2244.1602017481946
# FIT HON TENG vs CIFI HOLD GP ---> $ 2897.462205884992
# FIT HON TENG vs BRILLIANCE CHI ---> $ 3853.499386159192
# FIT HON TENG vs ZHAOJIN MINING ---> $ -1169.4029819542675
# FIT HON TENG vs EB SECURITIES ---> $ 2143.3698519123254
# HAITONG SEC vs ICBC ---> $ 586.4572900958483
# HAITONG SEC vs BANK OF CHINA ---> $ 1177.4562229660423
# HAITONG SEC vs WH GROUP ---> $ 357.0070060112739
# HAITONG SEC vs SINOPEC CORP ---> $ 854.1053513497027
# HAITONG SEC vs ABC ---> $ -552.4105831910529
# HAITONG SEC vs PETROCHINA ---> $ 4093.5972275192
# HAITONG SEC vs CITIC BANK ---> $ 299.60789271322756
# HAITONG SEC vs GREENTOWN SER ---> $ -192.61793112347004
# HAITONG SEC vs CHINA TELECOM ---> $ 680.5083343902079
# HAITONG SEC vs GOME RETAIL ---> $ -934.8855118600995
# HAITONG SEC vs PICC GROUP ---> $ -676.6421950877193
# HAITONG SEC vs CHINA DONGXIANG ---> $ -174.38413428488457
# 3SBIO vs SINO BIOPHARM ---> $ -2564.191585856456
# GOME RETAIL vs CCB ---> $ -3345.078863852774
# GOME RETAIL vs COUNTRY GARDEN ---> $ -2933.976754520795
# GOME RETAIL vs WH GROUP ---> $ 7178.108766926702
# GOME RETAIL vs PETROCHINA ---> $ 6479.091874720395
# GOME RETAIL vs CIFI HOLD GP ---> $ 667.862637285767
# GOME RETAIL vs BRILLIANCE CHI ---> $ -3952.852232265128
# GOME RETAIL vs GREENTOWN SER ---> $ 1558.5891562366633
# GOME RETAIL vs HAITONG SEC ---> $ -5963.209534758411
# GOME RETAIL vs PICC GROUP ---> $ 3018.2718863397386
# GOME RETAIL vs HOPE EDU ---> $ -636.2336720978637
# GOME RETAIL vs ZHAOJIN MINING ---> $ -2530.63839420722
# PICC GROUP vs COUNTRY GARDEN ---> $ -2805.7060335738242
# PICC GROUP vs WH GROUP ---> $ -2063.5063862876777
# PICC GROUP vs GREENTOWN SER ---> $ -1736.5709521459758
# PICC GROUP vs HAITONG SEC ---> $ -40.133693678806594
# PICC GROUP vs GOME RETAIL ---> $ -1405.890514341796
# PICC GROUP vs ZHAOJIN MINING ---> $ 1708.19333722159
# PICC GROUP vs CHINA DONGXIANG ---> $ -53.40707069289601
# AIR CHINA vs SINOPEC CORP ---> $ 3635.908620557084
# AIR CHINA vs GREENTOWN SER ---> $ 2848.694446928943
# AIR CHINA vs GAC GROUP ---> $ -1909.4714593737463
# AIR CHINA vs HOPE EDU ---> $ 3607.123330035445
# GAC GROUP vs AIR CHINA ---> $ -1486.5687688894968
# GAC GROUP vs FL2 CSOP HSI ---> $ -681.7464670468335
# HENGTEN NET vs COUNTRY GARDEN ---> $ -4708.797353267252
# HENGTEN NET vs CHINARES CEMENT ---> $ -1219.9886895142336
# HENGTEN NET vs CHINA SHENHUA ---> $ 7108.91285738763
# HENGTEN NET vs CNBM ---> $ 3802.3213786985516
# HENGTEN NET vs KWG GROUP ---> $ -3211.1121136747342
# HENGTEN NET vs ZOOMLION ---> $ -3374.349169600636
# HENGTEN NET vs ZHAOJIN MINING ---> $ 1630.7043787092998
# HENGTEN NET vs EB SECURITIES ---> $ -2620.8223352666355
# CGS vs COUNTRY GARDEN ---> $ 594.9829046466002
# CGS vs CIFI HOLD GP ---> $ -1241.5479047509507
# CGS vs GREENTOWN SER ---> $ -96.67463489061265
# CGS vs CHINA YOUZAN ---> $ 6350.617488758754
# CGS vs ZHAOJIN MINING ---> $ 3172.9306115149566
# CGS vs CHINA DONGXIANG ---> $ -408.58770311371336
# HOPE EDU vs COUNTRY GARDEN ---> $ -4093.512107909467
# HOPE EDU vs PETROCHINA ---> $ 7708.1837298313185
# HOPE EDU vs CIFI HOLD GP ---> $ 6378.3316254621295
# HOPE EDU vs CITIC BANK ---> $ 3120.352171650673
# HOPE EDU vs BRILLIANCE CHI ---> $ 695.2660913271266
# HOPE EDU vs GREENTOWN SER ---> $ -888.6967593041154
# HOPE EDU vs GOME RETAIL ---> $ -5546.387295278238
# HOPE EDU vs AIR CHINA ---> $ 282.82182023710993
# HOPE EDU vs ZHAOJIN MINING ---> $ -6419.809432293629
# VIVA BIOTECH vs COMEC ---> $ 1195.2627193623848
# YONGDA AUTO vs ZIJIN MINING ---> $ -1151.1046596849
# DONGFENG GROUP vs JXR ---> $ -360.16724506428363
# DONGFENG GROUP vs CHINASOFT INT'L ---> $ 8544.439575289596
# CHINASOFT INT'L vs CHINA SHENHUA ---> $ -557.3973389695075
# CHINASOFT INT'L vs ND PAPER ---> $ 5920.781698264316
# CHINASOFT INT'L vs DONGFENG GROUP ---> $ 7849.357623285295
# CSC vs COMEC ---> $ -393.8479810196932
# UNITED LAB vs COMEC ---> $ -1788.6322660763144
# COFCO MEAT vs COUNTRY GARDEN ---> $ 835.7282523770909
# COFCO MEAT vs CHINARES CEMENT ---> $ 286.2303326952442
# COFCO MEAT vs CIFI HOLD GP ---> $ 1066.2137557803862
# COFCO MEAT vs CNBM ---> $ 10893.567096468614
# COFCO MEAT vs BRILLIANCE CHI ---> $ -878.2355111454326
# COFCO MEAT vs GREENTOWN SER ---> $ 7141.884069309484
# COFCO MEAT vs ZHAOJIN MINING ---> $ 3322.414301014177
# CMOC vs COUNTRY GARDEN ---> $ 878.5510037599761
# CMOC vs ZHAOJIN MINING ---> $ 3012.1964129891603
# CMOC vs FL2 CSOP HSI ---> $ -1179.1366436680482
# ZOOMLION vs CHINA SHENHUA ---> $ 5841.7096223569315
# ZOOMLION vs CNBM ---> $ 1082.165047261531
# ZOOMLION vs AVICHINA ---> $ 2589.7448580430837
# ZOOMLION vs HENGTEN NET ---> $ -4926.73696493639
# ZHAOJIN MINING vs BANK OF CHINA ---> $ 5288.825343985542
# ZHAOJIN MINING vs COUNTRY GARDEN ---> $ 1571.703719692916
# ZHAOJIN MINING vs SINOPEC CORP ---> $ 6209.642564425829
# ZHAOJIN MINING vs ABC ---> $ 3924.572477130576
# ZHAOJIN MINING vs PETROCHINA ---> $ 11723.99101213288
# ZHAOJIN MINING vs KUNLUN ENERGY ---> $ 10676.008435003234
# ZHAOJIN MINING vs CIFI HOLD GP ---> $ 2541.700172295923
# ZHAOJIN MINING vs CITIC BANK ---> $ 5166.392839057422
# ZHAOJIN MINING vs SJM HOLDINGS ---> $ 295.3273543973155
# ZHAOJIN MINING vs CHINA SHENHUA ---> $ 8265.454507072289
# ZHAOJIN MINING vs KWG GROUP ---> $ 2039.2872485746648
# ZHAOJIN MINING vs BRILLIANCE CHI ---> $ 4158.852011113833
# ZHAOJIN MINING vs CHINA TELECOM ---> $ 6443.399361645236
# ZHAOJIN MINING vs AVICHINA ---> $ 1595.173717970948
# ZHAOJIN MINING vs CHINA YOUZAN ---> $ -2356.573256667675
# ZHAOJIN MINING vs FIT HON TENG ---> $ -234.9591779252396
# ZHAOJIN MINING vs GOME RETAIL ---> $ 1873.837535010156
# ZHAOJIN MINING vs PICC GROUP ---> $ 4229.540882303458
# ZHAOJIN MINING vs HENGTEN NET ---> $ 1495.2994649699685
# ZHAOJIN MINING vs CGS ---> $ 4045.736071029647
# ZHAOJIN MINING vs HOPE EDU ---> $ -116.6141699590662
# ZHAOJIN MINING vs COFCO MEAT ---> $ 3640.9371535207974
# ZHAOJIN MINING vs CMOC ---> $ 3012.1964129891603
# ZHAOJIN MINING vs EB SECURITIES ---> $ 3210.7619796645104
# ZHAOJIN MINING vs CHINA DONGXIANG ---> $ 4264.355236253321
# COMEC vs SJM HOLDINGS ---> $ 3661.742590668179
# COMEC vs KWG GROUP ---> $ -1511.8164165504913
# COMEC vs VIVA BIOTECH ---> $ -1575.0740884988263
# COMEC vs CSC ---> $ -340.0049259944044
# COMEC vs UNITED LAB ---> $ -3454.5199832297512
# COMEC vs EB SECURITIES ---> $ 51.601330997275
# EB SECURITIES vs KWG GROUP ---> $ -1782.651632873427
# EB SECURITIES vs AVICHINA ---> $ -1615.5882616935623
# EB SECURITIES vs CHINA YOUZAN ---> $ -5567.335236332186
# EB SECURITIES vs FIT HON TENG ---> $ 2198.6998560776174
# EB SECURITIES vs HENGTEN NET ---> $ -1715.4625146945418
# EB SECURITIES vs ZHAOJIN MINING ---> $ -723.1948072060404
# EB SECURITIES vs COMEC ---> $ -1238.152236853337
# CHINA DONGXIANG vs COUNTRY GARDEN ---> $ -4389.098318015122
# CHINA DONGXIANG vs WH GROUP ---> $ -1678.1935369956445
# CHINA DONGXIANG vs PETROCHINA ---> $ 7297.937365249369
# CHINA DONGXIANG vs CIFI HOLD GP ---> $ -4087.766388823118
# CHINA DONGXIANG vs BRILLIANCE CHI ---> $ -313.851485684032
# CHINA DONGXIANG vs GREENTOWN SER ---> $ -1906.6475694415003
# CHINA DONGXIANG vs HAITONG SEC ---> $ -305.965175402971
# CHINA DONGXIANG vs PICC GROUP ---> $ -4746.579565284315
# CHINA DONGXIANG vs CGS ---> $ -218.61916522367392
# CHINA DONGXIANG vs ZHAOJIN MINING ---> $ 3061.240929255935
# FI2 CSOP HSI vs PICC P&C ---> $ 2239.7309625150447
# FL2 CSOP HSI vs GAC GROUP ---> $ 446.2303447734821
# FL2 CSOP HSI vs CMOC ---> $ 975.1719005204759
# CHINA MOBILE vs SUNAC ---> $ 4830.621949872878
# CHINA MOBILE vs WHARF REIC ---> $ -1954.2186103800104
# CHINA MOBILE vs WHARF HOLDINGS ---> $ 1035.2958454078725
# CHINA MOBILE vs KOOLEARN ---> $ 6359.938807146398
# CHINA MOBILE vs BROAD HOMES ---> $ -5845.388137351179
# HSBC HOLDINGS vs WHARF REIC ---> $ -975.41936430225
# HSBC HOLDINGS vs WHARF HOLDINGS ---> $ 2014.095091485633
# HSBC HOLDINGS vs KOOLEARN ---> $ 6851.187741583957
# HSBC HOLDINGS vs BROAD HOMES ---> $ -4866.588891273418
# SANDS CHINA LTD vs MTR CORPORATION ---> $ 4467.047821284366
# SANDS CHINA LTD vs WHARF REIC ---> $ 4971.679403849081
# SANDS CHINA LTD vs CONCH VENTURE ---> $ 4831.494942737076
# SANDS CHINA LTD vs WHARF HOLDINGS ---> $ 7961.193859636964
# SANDS CHINA LTD vs KOOLEARN ---> $ 3516.5578511553904
# SANDS CHINA LTD vs BROAD HOMES ---> $ 1080.5098768779126
# MTR CORPORATION vs SANDS CHINA LTD ---> $ 4065.677855247405
# MTR CORPORATION vs WHARF REIC ---> $ -217.45516624582524
# MTR CORPORATION vs CONCH VENTURE ---> $ 495.0171215818227
# MTR CORPORATION vs WHARF HOLDINGS ---> $ 2772.0592895420577
# MTR CORPORATION vs KOOLEARN ---> $ 8149.797850888184
# MTR CORPORATION vs BROAD HOMES ---> $ -4108.624693216993
# CHINA RES LAND vs NEWWORLDDEV-NEW ---> $ 1394.285465610168
# CHINA RES LAND vs WHARF REIC ---> $ -989.0152744324223
# CHINA RES LAND vs WHARF HOLDINGS ---> $ 2000.4991813554607
# CHINA RES LAND vs KOOLEARN ---> $ 7107.525667675505
# CHINA RES LAND vs BROAD HOMES ---> $ -4880.18480140359
# LONGFOR GROUP vs WHARF REIC ---> $ 1563.930004878699
# LONGFOR GROUP vs WHARF HOLDINGS ---> $ 4553.444460666582
# LONGFOR GROUP vs BROAD HOMES ---> $ -2327.239522092469
# GALAXY ENT vs WHARF REIC ---> $ 3076.8407814147413
# GALAXY ENT vs WHARF HOLDINGS ---> $ 5162.734901196155
# GALAXY ENT vs BROAD HOMES ---> $ -1744.073630452719
# HANSOH PHARMA vs WHARF REIC ---> $ 4425.015547010142
# HANSOH PHARMA vs WHARF HOLDINGS ---> $ 7414.530002798025
# HANSOH PHARMA vs BROAD HOMES ---> $ 533.8460200389736
# CKH HOLDINGS vs WHARF REIC ---> $ 1.4340124331301922
# CKH HOLDINGS vs WHARF HOLDINGS ---> $ 2990.948468221013
# CKH HOLDINGS vs KOOLEARN ---> $ 8601.483858165313
# CKH HOLDINGS vs BROAD HOMES ---> $ -3889.735514538038
# HAIDILAO vs WHARF REIC ---> $ 2314.344799701158
# HAIDILAO vs WHARF HOLDINGS ---> $ 7922.376606535727
# HAIDILAO vs BROAD HOMES ---> $ 2455.1912219611795
# CHINA RES BEER vs WHARF REIC ---> $ 336.37160367452
# CHINA RES BEER vs WHARF HOLDINGS ---> $ 5887.102095511707
# CHINA RES BEER vs BROAD HOMES ---> $ 5123.604179598832
# CM BANK vs WHARF REIC ---> $ -1465.4908435675097
# CM BANK vs WHARF HOLDINGS ---> $ -4206.391325518931
# CM BANK vs BROAD HOMES ---> $ 2806.4342959516425
# SUNAC vs CHINA MOBILE ---> $ 4185.0760800981825
# SUNAC vs WHARF REIC ---> $ 3473.3454664851015
# SUNAC vs A-LIVING ---> $ 189.38588060098027
# SUNAC vs WHARF HOLDINGS ---> $ 6462.8599222729845
# SUNAC vs KOOLEARN ---> $ 143.46804309673553
# SUNAC vs BROAD HOMES ---> $ -417.8240604860666
# CK ASSET vs WHARF REIC ---> $ -1911.8409098302072
# CK ASSET vs A-LIVING ---> $ 178.8618468930008
# CK ASSET vs WHARF HOLDINGS ---> $ 1077.6735459576757
# CK ASSET vs KOOLEARN ---> $ 8368.695409378653
# CK ASSET vs BROAD HOMES ---> $ -5803.010436801375
# MENGNIU DAIRY vs WHARF REIC ---> $ -1029.9484038397277
# MENGNIU DAIRY vs KINGSOFT ---> $ 2111.5004466085675
# MENGNIU DAIRY vs WHARF HOLDINGS ---> $ 1959.5660519481553
# MENGNIU DAIRY vs XD INC ---> $ -3488.742835184009
# MENGNIU DAIRY vs BROAD HOMES ---> $ -4985.635987358953
# CG SERVICES vs WHARF REIC ---> $ -4008.926059307736
# CG SERVICES vs KINGSOFT ---> $ 891.3227043932329
# CG SERVICES vs WHARF HOLDINGS ---> $ -3212.5880205362682
# CG SERVICES vs BROAD HOMES ---> $ -1088.3934412874887
# ZHONGSHENG HLDG vs WHARF REIC ---> $ -1279.7588975924446
# ZHONGSHENG HLDG vs WHARF HOLDINGS ---> $ 1999.4893832174403
# ZHONGSHENG HLDG vs BROAD HOMES ---> $ 1381.0918507738925
# NEWWORLDDEV-NEW vs CHINA RES LAND ---> $ 2894.449061451898
# NEWWORLDDEV-NEW vs WHARF REIC ---> $ 1034.3300667713975
# NEWWORLDDEV-NEW vs WHARF HOLDINGS ---> $ 4023.8445225592804
# NEWWORLDDEV-NEW vs KOOLEARN ---> $ 6467.926789438086
# NEWWORLDDEV-NEW vs BROAD HOMES ---> $ -2856.8394601997707
# CHINA RES GAS vs WHARF REIC ---> $ -269.1274787137081
# CHINA RES GAS vs WHARF HOLDINGS ---> $ 2720.386977074175
# CHINA RES GAS vs KOOLEARN ---> $ 8201.470163356067
# CHINA RES GAS vs BROAD HOMES ---> $ -4160.297005684876
# WHARF REIC vs CHINA MOBILE ---> $ 1954.2186103800104
# WHARF REIC vs HSBC HOLDINGS ---> $ 975.41936430225
# WHARF REIC vs SANDS CHINA LTD ---> $ -1964.1368015605385
# WHARF REIC vs MTR CORPORATION ---> $ 217.45516624582524
# WHARF REIC vs CHINA RES LAND ---> $ 989.0152744324223
# WHARF REIC vs LONGFOR GROUP ---> $ -1563.930004878699
# WHARF REIC vs GALAXY ENT ---> $ -1712.358201651944
# WHARF REIC vs HANSOH PHARMA ---> $ -4689.891435860925
# WHARF REIC vs CKH HOLDINGS ---> $ -1.4340124331301922
# WHARF REIC vs HAIDILAO ---> $ -4942.290157697777
# WHARF REIC vs CHINA RES BEER ---> $ -1761.5039501036708
# WHARF REIC vs CM BANK ---> $ 3594.7661961966405
# WHARF REIC vs SUNAC ---> $ 1194.4546384825762
# WHARF REIC vs CK ASSET ---> $ 1911.8409098302072
# WHARF REIC vs MENGNIU DAIRY ---> $ 1029.9484038397277
# WHARF REIC vs CG SERVICES ---> $ 1515.6812241368825
# WHARF REIC vs ZHONGSHENG HLDG ---> $ 1788.749869847703
# WHARF REIC vs NEWWORLDDEV-NEW ---> $ -1034.3300667713975
# WHARF REIC vs CHINA RES GAS ---> $ 269.1274787137081
# WHARF REIC vs CONCH CEMENT ---> $ -437.55695174755056
# WHARF REIC vs AAC TECH ---> $ -1311.480338519712
# WHARF REIC vs CONCH VENTURE ---> $ 212.24972751550558
# WHARF REIC vs A-LIVING ---> $ -1091.7307311270451
# WHARF REIC vs KINGSOFT ---> $ -3954.2632363038283
# WHARF REIC vs WHARF HOLDINGS ---> $ 3534.7157015951198
# WHARF REIC vs KOOLEARN ---> $ 5451.026868550811
# WHARF REIC vs ZA ONLINE ---> $ -749.2358417642372
# WHARF REIC vs FOSUN PHARMA ---> $ 2356.86584729447
# WHARF REIC vs XD INC ---> $ -1437.435788514802
# WHARF REIC vs BROAD HOMES ---> $ -3891.169526971168
# CONCH CEMENT vs WHARF REIC ---> $ 149.67475805103095
# CONCH CEMENT vs A-LIVING ---> $ -816.9493442088606
# CONCH CEMENT vs WHARF HOLDINGS ---> $ 3139.189213838914
# CONCH CEMENT vs KOOLEARN ---> $ 7162.529571180517
# CONCH CEMENT vs BROAD HOMES ---> $ -3741.494768920137
# AAC TECH vs WHARF REIC ---> $ 1023.5702393329175
# AAC TECH vs WHARF HOLDINGS ---> $ 4013.0846951208005
# AAC TECH vs KOOLEARN ---> $ 4413.51768633637
# AAC TECH vs BROAD HOMES ---> $ -2867.5992876382506
# LI NING vs BROAD HOMES ---> $ 13156.477435855319
# CONCH VENTURE vs SANDS CHINA LTD ---> $ 6189.195221298427
# CONCH VENTURE vs MTR CORPORATION ---> $ 221.84278003674808
# CONCH VENTURE vs WHARF REIC ---> $ -212.24972751550558
# CONCH VENTURE vs WHARF HOLDINGS ---> $ 2777.2647282723774
# CONCH VENTURE vs KOOLEARN ---> $ 8144.592412157865
# CONCH VENTURE vs BROAD HOMES ---> $ -4103.419254486674
# A-LIVING vs SUNAC ---> $ 3652.432946545521
# A-LIVING vs CK ASSET ---> $ 3003.5716409572524
# A-LIVING vs WHARF REIC ---> $ 1091.7307311270451
# A-LIVING vs CONCH CEMENT ---> $ -71.22907209192454
# A-LIVING vs WHARF HOLDINGS ---> $ 4081.245186914928
# A-LIVING vs KOOLEARN ---> $ 7305.723247029641
# A-LIVING vs BROAD HOMES ---> $ -2799.438795844123
# KINGSOFT vs MENGNIU DAIRY ---> $ 3876.1562429174255
# KINGSOFT vs CG SERVICES ---> $ 1912.1672313046147
# KINGSOFT vs WHARF REIC ---> $ 2515.0800540120063
# KINGSOFT vs WHARF HOLDINGS ---> $ 7165.741668110373
# KINGSOFT vs FOSUN PHARMA ---> $ 196.48706388598566
# KINGSOFT vs XD INC ---> $ 705.0271761008553
# KINGSOFT vs BROAD HOMES ---> $ 1415.944320619742
# WHARF HOLDINGS vs CHINA MOBILE ---> $ -1035.2958454078725
# WHARF HOLDINGS vs HSBC HOLDINGS ---> $ -2014.095091485633
# WHARF HOLDINGS vs SANDS CHINA LTD ---> $ -7937.367232999701
# WHARF HOLDINGS vs MTR CORPORATION ---> $ -2772.0592895420577
# WHARF HOLDINGS vs CHINA RES LAND ---> $ -2000.4991813554607
# WHARF HOLDINGS vs LONGFOR GROUP ---> $ -4553.444460666582
# WHARF HOLDINGS vs GALAXY ENT ---> $ -4923.132853642731
# WHARF HOLDINGS vs HANSOH PHARMA ---> $ -7414.530002798025
# WHARF HOLDINGS vs CKH HOLDINGS ---> $ -2990.948468221013
# WHARF HOLDINGS vs HAIDILAO ---> $ -7800.905060424395
# WHARF HOLDINGS vs CHINA RES BEER ---> $ -4751.018405891554
# WHARF HOLDINGS vs CM BANK ---> $ 605.2517404087575
# WHARF HOLDINGS vs SUNAC ---> $ -7690.141919215039
# WHARF HOLDINGS vs CK ASSET ---> $ -1077.6735459576757
# WHARF HOLDINGS vs MENGNIU DAIRY ---> $ -1959.5660519481553
# WHARF HOLDINGS vs CG SERVICES ---> $ -1473.8332316510005
# WHARF HOLDINGS vs ZHONGSHENG HLDG ---> $ -1200.76458594018
# WHARF HOLDINGS vs NEWWORLDDEV-NEW ---> $ -4023.8445225592804
# WHARF HOLDINGS vs CHINA RES GAS ---> $ -2720.386977074175
# WHARF HOLDINGS vs WHARF REIC ---> $ -2989.514455787883
# WHARF HOLDINGS vs CONCH CEMENT ---> $ -3139.189213838914
# WHARF HOLDINGS vs AAC TECH ---> $ -4013.0846951208005
# WHARF HOLDINGS vs CONCH VENTURE ---> $ -2777.2647282723774
# WHARF HOLDINGS vs A-LIVING ---> $ -4081.245186914928
# WHARF HOLDINGS vs KINGSOFT ---> $ -6943.777692091711
# WHARF HOLDINGS vs KOOLEARN ---> $ 726.529126432135
# WHARF HOLDINGS vs ZA ONLINE ---> $ -3738.75029755212
# WHARF HOLDINGS vs FOSUN PHARMA ---> $ -632.6486084934131
# WHARF HOLDINGS vs XD INC ---> $ -4426.950244302685
# WHARF HOLDINGS vs BROAD HOMES ---> $ -6880.683982759051
# KOOLEARN vs CHINA MOBILE ---> $ 9839.268008763895
# KOOLEARN vs HSBC HOLDINGS ---> $ 8907.762048944609
# KOOLEARN vs SANDS CHINA LTD ---> $ 2960.6632807932783
# KOOLEARN vs MTR CORPORATION ---> $ 8149.797850888184
# KOOLEARN vs CHINA RES LAND ---> $ 8921.357959074781
# KOOLEARN vs CKH HOLDINGS ---> $ 7930.908672209229
# KOOLEARN vs SUNAC ---> $ 4458.9972181572575
# KOOLEARN vs CK ASSET ---> $ 9844.183594472566
# KOOLEARN vs NEWWORLDDEV-NEW ---> $ 6898.012617870962
# KOOLEARN vs CHINA RES GAS ---> $ 8201.470163356067
# KOOLEARN vs WHARF REIC ---> $ 7932.342684642359
# KOOLEARN vs CONCH CEMENT ---> $ 7538.272241113154
# KOOLEARN vs AAC TECH ---> $ 6908.7724453094415
# KOOLEARN vs CONCH VENTURE ---> $ 8144.592412157865
# KOOLEARN vs A-LIVING ---> $ 6840.611953515314
# KOOLEARN vs WHARF HOLDINGS ---> $ 10921.857140430242
# KOOLEARN vs BROAD HOMES ---> $ 4041.173157671191
# ZA ONLINE vs WHARF REIC ---> $ -1671.4942828650728
# ZA ONLINE vs WHARF HOLDINGS ---> $ -974.1874043741245
# ZA ONLINE vs BROAD HOMES ---> $ -8129.496909327759
# FOSUN PHARMA vs WHARF REIC ---> $ 595.6783518364027
# FOSUN PHARMA vs KINGSOFT ---> $ -5257.2411756707515
# FOSUN PHARMA vs WHARF HOLDINGS ---> $ 300.32903801011616
# FOSUN PHARMA vs BROAD HOMES ---> $ 1538.0390261085631
# XD INC vs MENGNIU DAIRY ---> $ -80.55846256304176
# XD INC vs WHARF REIC ---> $ -749.5061172158375
# XD INC vs KINGSOFT ---> $ 2839.794682560213
# XD INC vs WHARF HOLDINGS ---> $ 1953.4056402745273
# XD INC vs BROAD HOMES ---> $ -3101.851511737239
# YEAHKA vs CC NEW LIFE ---> $ 463.39374818368833
# CC NEW LIFE vs YEAHKA ---> $ -1973.1540995591113
# BROAD HOMES vs CHINA MOBILE ---> $ 5845.388137351179
# BROAD HOMES vs HSBC HOLDINGS ---> $ 4866.588891273418
# BROAD HOMES vs SANDS CHINA LTD ---> $ -1080.5098768779126
# BROAD HOMES vs MTR CORPORATION ---> $ 4108.624693216993
# BROAD HOMES vs CHINA RES LAND ---> $ 4880.18480140359
# BROAD HOMES vs LONGFOR GROUP ---> $ 2327.239522092469
# BROAD HOMES vs GALAXY ENT ---> $ 814.3287455564268
# BROAD HOMES vs HANSOH PHARMA ---> $ -533.8460200389736
# BROAD HOMES vs CKH HOLDINGS ---> $ 3889.735514538038
# BROAD HOMES vs HAIDILAO ---> $ -920.2210776653437
# BROAD HOMES vs CHINA RES BEER ---> $ 2129.6655768674973
# BROAD HOMES vs CM BANK ---> $ 7485.935723167809
# BROAD HOMES vs SUNAC ---> $ 417.8240604860666
# BROAD HOMES vs CK ASSET ---> $ 5803.010436801375
# BROAD HOMES vs MENGNIU DAIRY ---> $ 4921.117930810896
# BROAD HOMES vs CG SERVICES ---> $ 5406.850751108051
# BROAD HOMES vs ZHONGSHENG HLDG ---> $ 5679.919396818871
# BROAD HOMES vs NEWWORLDDEV-NEW ---> $ 2856.8394601997707
# BROAD HOMES vs CHINA RES GAS ---> $ 4160.297005684876
# BROAD HOMES vs WHARF REIC ---> $ 3891.169526971168
# BROAD HOMES vs CONCH CEMENT ---> $ 3741.494768920137
# BROAD HOMES vs AAC TECH ---> $ 2867.5992876382506
# BROAD HOMES vs LI NING ---> $ 10702.718255362419
# BROAD HOMES vs CONCH VENTURE ---> $ 4103.419254486674
# BROAD HOMES vs A-LIVING ---> $ 2799.438795844123
# BROAD HOMES vs KINGSOFT ---> $ -63.09370933266018
# BROAD HOMES vs WHARF HOLDINGS ---> $ 6880.683982759051
# BROAD HOMES vs KOOLEARN ---> $ -4041.173157671191
# BROAD HOMES vs ZA ONLINE ---> $ 3141.933685206931
# BROAD HOMES vs FOSUN PHARMA ---> $ 6248.035374265638
# BROAD HOMES vs XD INC ---> $ 2453.733738456366
# XIAOMI-W vs GENSCRIPT BIO ---> $ 10329.396656737157
# XIAOMI-W vs FLAT GLASS ---> $ 5049.594170912741
# BUD APAC vs ALI HEALTH ---> $ -2889.0475863682923
# BUD APAC vs CHINA LIFE ---> $ 1042.4118529894095
# BUD APAC vs CHINA FEIHE ---> $ -830.275512365235
# BUD APAC vs CITIC SEC ---> $ 4317.934906748664
# BUD APAC vs WEICHAI POWER ---> $ 3280.8182331009666
# BUD APAC vs NCI ---> $ 1151.9472208435373
# BUD APAC vs GENSCRIPT BIO ---> $ 20966.05935760106
# BUD APAC vs SD GOLD ---> $ 678.3436817076545
# BUD APAC vs CRRC TIMES ELEC ---> $ 1901.421323543399
# EVERGRANDE vs GENSCRIPT BIO ---> $ 26829.79595005482
# EVERG HEALTH vs GENSCRIPT BIO ---> $ 1560.2744026451583
# ALI HEALTH vs BUD APAC ---> $ 4290.002746302345
# ALI HEALTH vs CPIC ---> $ 2235.946976092264
# ALI HEALTH vs CHINA VANKE ---> $ 3987.387455025543
# ALI HEALTH vs NCI ---> $ 2524.432500161136
# ALI HEALTH vs GENSCRIPT BIO ---> $ 19046.45193625323
# CHINA OVERSEAS vs GENSCRIPT BIO ---> $ 17386.594327382383
# CHINA OVERSEAS vs AK MEDICAL ---> $ -4531.798699489267
# CHINA OVERSEAS vs ZTE ---> $ 1332.146543703353
# BOC HONG KONG vs CHINA TAIPING ---> $ 2028.1500224067104
# BOC HONG KONG vs CHINA VANKE ---> $ 1491.0289231365232
# BOC HONG KONG vs GENSCRIPT BIO ---> $ 18759.474791950557
# SMIC vs GENSCRIPT BIO ---> $ 14836.245678856243
# GEELY AUTO vs XINYI GLASS ---> $ 2687.8464547941294
# GEELY AUTO vs GENSCRIPT BIO ---> $ 12245.030898493638
# CHINA LIFE vs BUD APAC ---> $ 96.79632258285892
# CHINA LIFE vs GENSCRIPT BIO ---> $ 20907.41095041226
# CHINA LIFE vs CRRC TIMES ELEC ---> $ 1842.7729163545955
# CHINA FEIHE vs BUD APAC ---> $ -1556.5235947588371
# CHINA FEIHE vs CPIC ---> $ -1141.9014970571461
# CHINA FEIHE vs CHINA TAIPING ---> $ 1110.8200770241992
# CHINA FEIHE vs WEICHAI POWER ---> $ 3049.755054237078
# CHINA FEIHE vs NCI ---> $ 428.068087474021
# CHINA FEIHE vs GENSCRIPT BIO ---> $ 23431.505369676757
# CHINA GAS HOLD vs GENSCRIPT BIO ---> $ 21450.00129796211
# SHIMAO GROUP vs GENSCRIPT BIO ---> $ 22385.830741129794
# SHIMAO GROUP vs AK MEDICAL ---> $ 4090.7922583799154
# WEIGAO GROUP vs NCI ---> $ 40.81959502243808
# WEIGAO GROUP vs GENSCRIPT BIO ---> $ 20627.62237035
# GUANGDONG INV vs GENSCRIPT BIO ---> $ 21661.76440857548
# MICROPORT vs GENSCRIPT BIO ---> $ -15233.449316219298
# KINGDEE INT'L vs GENSCRIPT BIO ---> $ 12314.383208668762
# WYNN MACAU vs CHINA TAIPING ---> $ 4009.107379707515
# WYNN MACAU vs CHINA VANKE ---> $ 4142.814212016948
# WYNN MACAU vs GENSCRIPT BIO ---> $ 23834.877816785956
# WYNN MACAU vs SINOPHARM ---> $ 5997.364878346093
# CPIC vs ALI HEALTH ---> $ 4072.9475549391145
# CPIC vs CHINA FEIHE ---> $ -1202.5914845791904
# CPIC vs GENSCRIPT BIO ---> $ 21324.915345414556
# CPIC vs CRRC TIMES ELEC ---> $ 3237.7273806659578
# BYD ELECTRONIC vs GENSCRIPT BIO ---> $ 5521.752646286768
# ESR vs XINYI GLASS ---> $ 1256.1597794357622
# ESR vs GENSCRIPT BIO ---> $ 17100.14293958232
# ESR vs CRRC TIMES ELEC ---> $ 1098.2073134340098
# CHINA TAIPING vs BOC HONG KONG ---> $ 1095.599276473863
# CHINA TAIPING vs CHINA FEIHE ---> $ -1970.5644328878561
# CHINA TAIPING vs WYNN MACAU ---> $ 4531.4566336109865
# CHINA TAIPING vs CHINA VANKE ---> $ 148.99940433894153
# CHINA TAIPING vs GENSCRIPT BIO ---> $ 19825.77043707844
# CHINA TAIPING vs HTSC ---> $ 1311.634279017957
# CHINA TAIPING vs CRRC TIMES ELEC ---> $ 761.1324030207779
# CHINA VANKE vs ALI HEALTH ---> $ -2903.920254328139
# CHINA VANKE vs BOC HONG KONG ---> $ 777.3050613304631
# CHINA VANKE vs WYNN MACAU ---> $ 1070.9407268274772
# CHINA VANKE vs CHINA TAIPING ---> $ -742.9541621520966
# CHINA VANKE vs GENSCRIPT BIO ---> $ 20420.423031631355
# XINYI GLASS vs GEELY AUTO ---> $ 1102.1367367018938
# XINYI GLASS vs ESR ---> $ 2345.315295052571
# XINYI GLASS vs GENSCRIPT BIO ---> $ 12355.156539949758
# HUA HONG SEMI vs GENSCRIPT BIO ---> $ 673.1905586561352
# CITIC SEC vs BUD APAC ---> $ 2934.291485733829
# CITIC SEC vs WEICHAI POWER ---> $ -367.5103610454735
# CITIC SEC vs GENSCRIPT BIO ---> $ 16927.548883448188
# CITIC SEC vs CRRC TIMES ELEC ---> $ -2137.089150609474
# CICC vs NCI ---> $ 1921.433153027614
# CICC vs GENSCRIPT BIO ---> $ 19104.32179821575
# CICC vs CRRC TIMES ELEC ---> $ 39.683764158089616
# BEIJING ENT vs GENSCRIPT BIO ---> $ 16281.099201430387
# BEIJING ENT vs SINOPHARM ---> $ 722.5663180596275
# BEIJING ENT vs ZTE ---> $ 2.207558450874785
# WEICHAI POWER vs BUD APAC ---> $ 777.4413967484079
# WEICHAI POWER vs CHINA FEIHE ---> $ -2886.302404146749
# WEICHAI POWER vs CITIC SEC ---> $ 129.8806212219988
# WEICHAI POWER vs NCI ---> $ 234.34365573965988
# WEICHAI POWER vs GENSCRIPT BIO ---> $ 13268.87089369024
# WEICHAI POWER vs CRRC TIMES ELEC ---> $ -909.6344695822008
# NCI vs BUD APAC ---> $ 554.0018221534883
# NCI vs ALI HEALTH ---> $ -1682.317522617178
# NCI vs CHINA FEIHE ---> $ -1062.7791569784267
# NCI vs WEIGAO GROUP ---> $ -1700.4029593678024
# NCI vs CICC ---> $ 1629.2339147721177
# NCI vs WEICHAI POWER ---> $ 2578.552148512408
# NCI vs GENSCRIPT BIO ---> $ 20733.555712987873
# NCI vs SD GOLD ---> $ -1633.6180016159524
# GENSCRIPT BIO vs XIAOMI-W ---> $ -25187.75018299304
# GENSCRIPT BIO vs BUD APAC ---> $ -14401.378506489098
# GENSCRIPT BIO vs EVERGRANDE ---> $ 2587.4978216665604
# GENSCRIPT BIO vs EVERG HEALTH ---> $ -18329.467620833628
# GENSCRIPT BIO vs ALI HEALTH ---> $ -10533.491567193934
# GENSCRIPT BIO vs CHINA OVERSEAS ---> $ -7132.576223305205
# GENSCRIPT BIO vs BOC HONG KONG ---> $ -18165.963186834793
# GENSCRIPT BIO vs SMIC ---> $ -18025.597487963743
# GENSCRIPT BIO vs GEELY AUTO ---> $ -23052.42329174008
# GENSCRIPT BIO vs CHINA LIFE ---> $ -12428.224004759568
# GENSCRIPT BIO vs CHINA FEIHE ---> $ -14085.618062442885
# GENSCRIPT BIO vs CHINA GAS HOLD ---> $ -17064.16139796625
# GENSCRIPT BIO vs SHIMAO GROUP ---> $ -1978.7877723848915
# GENSCRIPT BIO vs WEIGAO GROUP ---> $ -16271.421432335108
# GENSCRIPT BIO vs GUANGDONG INV ---> $ -12435.04070169097
# GENSCRIPT BIO vs MICROPORT ---> $ -17015.365072621367
# GENSCRIPT BIO vs KINGDEE INT'L ---> $ -23282.883003869174
# GENSCRIPT BIO vs WYNN MACAU ---> $ -8198.26703519363
# GENSCRIPT BIO vs CPIC ---> $ -18440.76304836985
# GENSCRIPT BIO vs BYD ELECTRONIC ---> $ -21875.87897322916
# GENSCRIPT BIO vs ESR ---> $ -22419.59619418264
# GENSCRIPT BIO vs CHINA TAIPING ---> $ -15643.234434553186
# GENSCRIPT BIO vs CHINA VANKE ---> $ -11587.020925480518
# GENSCRIPT BIO vs XINYI GLASS ---> $ -17673.477440800976
# GENSCRIPT BIO vs HUA HONG SEMI ---> $ -18629.228228396958
# GENSCRIPT BIO vs CITIC SEC ---> $ -17326.741025187417
# GENSCRIPT BIO vs CICC ---> $ -21675.555783522428
# GENSCRIPT BIO vs BEIJING ENT ---> $ -14224.90153643459
# GENSCRIPT BIO vs WEICHAI POWER ---> $ -18169.523584988434
# GENSCRIPT BIO vs NCI ---> $ -12509.848553804744
# GENSCRIPT BIO vs AK MEDICAL ---> $ -2064.609737456447
# GENSCRIPT BIO vs MEIDONG AUTO ---> $ -16436.446278143634
# GENSCRIPT BIO vs SINOPHARM ---> $ -14673.009759777295
# GENSCRIPT BIO vs HTSC ---> $ -14885.163013231342
# GENSCRIPT BIO vs TIANNENG POWER ---> $ -20099.428486674395
# GENSCRIPT BIO vs ZTE ---> $ -15894.965018539158
# GENSCRIPT BIO vs SD GOLD ---> $ -12815.91418945634
# GENSCRIPT BIO vs CRRC TIMES ELEC ---> $ -19064.638034057665
# GENSCRIPT BIO vs FUYAO GLASS ---> $ -19444.941265095942
# GENSCRIPT BIO vs FLAT GLASS ---> $ -18352.87501422873
# GENSCRIPT BIO vs HEC PHARM ---> $ -2793.6108638009464
# AK MEDICAL vs CHINA OVERSEAS ---> $ 3514.7539790751025
# AK MEDICAL vs SHIMAO GROUP ---> $ 1528.4919393327773
# AK MEDICAL vs GENSCRIPT BIO ---> $ 20901.348306457487
# MEIDONG AUTO vs GENSCRIPT BIO ---> $ 4759.796089641459
# SINOPHARM vs WYNN MACAU ---> $ 5254.912453122787
# SINOPHARM vs BEIJING ENT ---> $ 1514.0345009234825
# SINOPHARM vs GENSCRIPT BIO ---> $ 17724.928364920088
# HTSC vs CHINA TAIPING ---> $ -114.49203110766575
# HTSC vs GENSCRIPT BIO ---> $ 18264.4451949566
# TIANNENG POWER vs GENSCRIPT BIO ---> $ 25309.89253354364
# ZTE vs CHINA OVERSEAS ---> $ 2660.8247908767153
# ZTE vs BEIJING ENT ---> $ 1437.0864169072374
# ZTE vs GENSCRIPT BIO ---> $ 15728.347258471369
# ZTE vs HEC PHARM ---> $ 8130.586786130853
# SD GOLD vs BUD APAC ---> $ 682.6169360215408
# SD GOLD vs NCI ---> $ 656.5377699593537
# SD GOLD vs GENSCRIPT BIO ---> $ 21390.093482947224
# CRRC TIMES ELEC vs BUD APAC ---> $ 1901.421323543399
# CRRC TIMES ELEC vs CHINA LIFE ---> $ 1842.7729163545955
# CRRC TIMES ELEC vs CPIC ---> $ 2838.7745037833756
# CRRC TIMES ELEC vs ESR ---> $ 3265.4014832069206
# CRRC TIMES ELEC vs CHINA TAIPING ---> $ 785.1913798930864
# CRRC TIMES ELEC vs CITIC SEC ---> $ -2137.089150609474
# CRRC TIMES ELEC vs CICC ---> $ 1258.3117523381643
# CRRC TIMES ELEC vs WEICHAI POWER ---> $ -2579.659862494749
# CRRC TIMES ELEC vs GENSCRIPT BIO ---> $ 19740.69009309209
# FUYAO GLASS vs GENSCRIPT BIO ---> $ -670.7081664564339
# FUYAO GLASS vs FLAT GLASS ---> $ 729.8800319750244
# FLAT GLASS vs XIAOMI-W ---> $ 5367.980718314774
# FLAT GLASS vs GENSCRIPT BIO ---> $ 1023.951583479774
# FLAT GLASS vs FUYAO GLASS ---> $ -687.9247509125744
# HEC PHARM vs GENSCRIPT BIO ---> $ 23858.93404460222
# HEC PHARM vs ZTE ---> $ 8130.586786130853
# =================================================================
# PortfolioPnl: $ 947723.7106236857
#          stockA         stocksB           Pnl
# 0       BABA-SW  TECHTRONIC IND   6903.274136
# 1       BABA-SW      YIHAI INTL  -4201.018186
# 2       BABA-SW       PHARMARON   7584.421616
# 3       TENCENT       MEITUAN-W   -286.637636
# 4     MEITUAN-W         TENCENT    370.130619
# ..          ...             ...           ...
# 763  FLAT GLASS        XIAOMI-W   5367.980718
# 764  FLAT GLASS   GENSCRIPT BIO   1023.951583
# 765  FLAT GLASS     FUYAO GLASS   -687.924751
# 766   HEC PHARM   GENSCRIPT BIO  23858.934045
# 767   HEC PHARM             ZTE   8130.586786
#
# [768 rows x 3 columns]
